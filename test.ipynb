# %% [markdown]
# # 🦙 LLaMA-2 Inference Notebook
# This notebook runs Meta's **LLaMA-2-7B** model on Colab GPU.
#
# **Steps:**
# 1. Install dependencies
# 2. Log in with your Hugging Face key
# 3. Load model and generate text

# %%
# !pip install -U transformers accelerate huggingface_hub

# %%
from huggingface_hub import login

# 🔑 Paste your Hugging Face token here
login(token="hf_your_token_here")

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline

model_id = "meta-llama/Llama-2-7b-hf"

tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id, device_map="auto")

pipe = pipeline("text-generation", model=model, tokenizer=tokenizer)

print(pipe("Hello, I am a LLaMA-2 model and I can", max_length=50))
